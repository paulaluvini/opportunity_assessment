# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap

# %%
DATASETS_OCCUPATIONS = "./datasets_occupations/"
DATASETS_LABOR = './datasets_labor_metropolitan_area/'
OUTPUTS_DIR = "./outputs_occupations/"

# %%
# Importo tipografía Punto
import os
path = os.path.join(os.path.expanduser('~'), 'Documents/Proyectos/herramientas/')
import matplotlib.font_manager as font_manager
from matplotlib import rcParams
font_dir = [path + 'Raleway/']
for font in font_manager.findSystemFonts(font_dir):
    font_manager.fontManager.addfont(font)
rcParams['font.family'] = 'Raleway'
font_manager.fontManager

# %% [markdown]
# ## Read files

# %%
data_2022 = pd.read_parquet(DATASETS_LABOR + "df_labor_usa_metropolitan_area_N2022.parquet",engine='fastparquet')
data_2022['NAICS_2022'] = data_2022['NAICS_2022'].astype(str) # Ensure NAICS is string*
data_2022['naics_level'] = data_2022['NAICS_2022'].str.len() # Add a column for NAICS code length
mask_5digit = data_2022["NAICS_2022"].str.len().eq(6) & data_2022["NAICS_2022"].str.isnumeric()
data_2022 = data_2022[mask_5digit]
print(data_2022.shape)
data_2022.head()
# Out:
# (213397, 4)
#   NAICS_2022 metropolitan statistical area/micropolitan statistical area  EMP  \
# 0     113110                                              10780             7
# 1     113110                                              11660             7
# 2     113110                                              12060            50
# 3     113110                                              12260            12
# 4     113110                                              12620            31
#
#    naics_level
# 0            6
# 1            6
# 2            6
# 3            6
# 4            6

# %%
data_2023= pd.read_parquet(DATASETS_LABOR + "df_labor_usa_metropolitan_area_2023.parquet",engine='fastparquet')
data_2023['NAICS2017'] = data_2023['NAICS2017'].astype(str) # Ensure NAICS is string*
data_2023['naics_level'] = data_2023['NAICS2017'].str.len() # Add a column for NAICS code length
mask_5digit = data_2023["NAICS2017"].str.len().eq(6) & data_2023["NAICS2017"].str.isnumeric()
data_2023 = data_2023[mask_5digit]
print(data_2023.shape)
data_2023.head()
# Out:
# (204024, 5)
#    NAICS2017  EMP STATE  \
# 5     115112   19  None
# 10    212321   15  None
# 15    221122   86  None
# 20    236115   28  None
# 21    236118   55  None
#
#    metropolitan statistical area/micropolitan statistical area  naics_level
# 5                                               10100                     6
# 10                                              10100                     6
# 15                                              10100                     6
# 20                                              10100                     6
# 21                                              10100                     6

# %%
sectors = pd.read_excel(DATASETS_LABOR + "Sector classification NAICS 11.25.xlsx", sheet_name='NAICS')
sectors.rename(columns={"2022 NAICS Codes": "NAICS_6"}, inplace=True)
sectors['NAICS_6'] = sectors["NAICS_6"].apply(lambda x: f'{x:06}')
sectors = sectors.loc[sectors["Relevance"] == "Core"]
sectors_6digits = sectors[['NAICS_6', 'Strategic Sector']].drop_duplicates(subset=["NAICS_6", "Strategic Sector"], keep="first")
sectors_6digits["NAICS_4"] = sectors_6digits["NAICS_6"].str[:4]
sectors_6digits["NAICS_5"] = sectors_6digits["NAICS_6"].str[:5]
sectors_6digits.head()
# Out:
#   NAICS_6 Strategic Sector NAICS_4 NAICS_5
# 0  336411        Aerospace    3364   33641
# 1  336412        Aerospace    3364   33641
# 2  336413        Aerospace    3364   33641
# 3  336414        Aerospace    3364   33641
# 4  336415        Aerospace    3364   33641

# %%
data_labor = pd.concat([data_2023, data_2022], ignore_index=True)

data_labor = (data_labor.assign(NAICS2017=lambda d: d["NAICS2017"].astype(str))
          .loc[lambda d: d["NAICS2017"].str.len().eq(6) & d["NAICS2017"].str.isnumeric()]
          .groupby(["metropolitan statistical area/micropolitan statistical area", "NAICS2017"], as_index=False).agg(EMP=("EMP","mean")))
data_labor["EMP"] = data_labor["EMP"].round().astype(int)
data_labor.head()
# Out:
#   metropolitan statistical area/micropolitan statistical area NAICS2017  EMP
# 0                                              10100             115112   19
# 1                                              10100             212321   15
# 2                                              10100             221122   86
# 3                                              10100             236115   28
# 4                                              10100             236118   55

# %%
# Select the metropolitan area of San Diego (41740) and sum the EMP values
data_labor_sd = data_labor.loc[data_labor["metropolitan statistical area/micropolitan statistical area"]=="41740"]
data_labor_sd["EMP"].sum()
# Out:
# 1386384

# %%
data_labor_sd.loc[data_labor_sd["NAICS2017"].isin(["336411", "336412", "336413", "336414", "336415", "336419", "332992", "332993", "332994", "336992", "336611", "336612"])].sum()
# Out:
# metropolitan statistical area/micropolitan statistical area         4174041740417404174041740
# NAICS2017                                                      336411336412336413336611336612
# EMP                                                                                     20134
# dtype: object

# %%
df_occupations = pd.read_excel(DATASETS_OCCUPATIONS + "all_data_M_2024.xlsx", sheet_name="All May 2024 data")
df_occupations["NAICS"] = df_occupations["NAICS"].astype(str)
df_occupations.head()
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS     NAICS_TITLE  \
# 0    99       U.S.          1         US  000000  Cross-industry
# 1    99       U.S.          1         US  000000  Cross-industry
# 2    99       U.S.          1         US  000000  Cross-industry
# 3    99       U.S.          1         US  000000  Cross-industry
# 4    99       U.S.          1         US  000000  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ... H_PCT75  \
# 0  cross-industry      1235  00-0000         All Occupations  ...   37.89
# 1  cross-industry      1235  11-0000  Management Occupations  ...    82.5
# 2  cross-industry      1235  11-1000          Top Executives  ...   81.01
# 3  cross-industry      1235  11-1010        Chief Executives  ...       #
# 4  cross-industry      1235  11-1011        Chief Executives  ...       #
#
#   H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY NAICS_CLEAN
# ...

# %%
print(df_occupations.shape)
df_occupations_det = df_occupations.loc[df_occupations["O_GROUP"]=="detailed"]
df_occupations_det.shape
# Out:
# (414437, 33)
# (307153, 33)

# %%
naics_ref = pd.read_excel(DATASETS_LABOR + "NAICS_EQUIVALENCE.xlsx")
naics_ref['naics_code'] = naics_ref['naics_code'].astype(str)
naics_ref.head()
# Out:
#   naics_code                           naics_description  level parent_code  \
# 0         11  Agriculture, Forestry, Fishing and Hunting      2         NaN
# 1        111                             Crop Production      3          11
# 2       1111                   Oilseed and Grain Farming      4         111
# 3      11111                             Soybean Farming      5         111
# 4     111110                             Soybean Farming      6        1111
#
#   automotive_subsector supply_chain_stage sector_alignment strategic_sector
# 0               Others             Others              NaN              NaN
# 1               Others             Others              NaN              NaN
# 2               Others             Others              NaN              NaN
# 3               Others             Others              NaN              NaN
# 4               Others             Others              NaN              NaN

# %%
df_occupations_det["NAICS_CLEAN"] = df_occupations_det["NAICS_CLEAN"].astype(str).str.upper().str.replace(r"[^0-9A-Z]", "", regex=True)
level_map = {"cross-industry": 0,"cross-industry, ownership": 0,"sector": 2,"3-digit": 3,"3-digit, ownership": 3,"4-digit": 4,"4-digit, ownership": 4,
    "5-digit": 5,"6-digit": 6,}
df_occupations_det["i_group_clean"] = df_occupations_det["I_GROUP"].astype(str).str.strip().str.lower()
df_occupations_det["naics_len"] = df_occupations_det["i_group_clean"].map(level_map)
df_occupations_det["naics_len"].unique()
# Out:
# <ipython-input-13-a74e25ff2590>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_occupations_det["NAICS_CLEAN"] = df_occupations_det["NAICS_CLEAN"].astype(str).str.upper().str.replace(r"[^0-9A-Z]", "", regex=True)
# <ipython-input-13-a74e25ff2590>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_occupations_det["i_group_clean"] = df_occupations_det["I_GROUP"].astype(str).str.strip().str.lower()
# <ipython-input-13-a74e25ff2590>:5: SettingWithCopyWarning:
# ...

# %%
df_occupations_det = df_occupations_det.merge(naics_ref[['naics_code', 'naics_description', 'parent_code']], left_on=['NAICS_CLEAN'], right_on=['naics_code'], how='left')

# %%
df_california = pd.read_excel(DATASETS_OCCUPATIONS + "oes_research_2023_california.xlsx")
df_california["NAICS_CLEAN"] = df_california["NAICS_CLEAN"].astype(str).str.upper().str.replace(r"[^0-9A-Z]", "", regex=True)
level_map = {"cross-industry": 0,"cross-industry, ownership": 0,"sector": 2,"3-digit": 3,"3-digit, ownership": 3,"4-digit": 4,"4-digit, ownership": 4,
    "5-digit": 5,"6-digit": 6,}
df_california["i_group_clean"] = df_california["I_GROUP"].astype(str).str.strip().str.lower()
df_california["naics_len"] = df_california["i_group_clean"].map(level_map)
df_california.head()
# Out:
#    AREA  AREA_TITLE NAICS                                 NAICS_TITLE I_GROUP  \
# 0     6  California    11  Agriculture, Forestry, Fishing and Hunting  sector
# 1     6  California    11  Agriculture, Forestry, Fishing and Hunting  sector
# 2     6  California    11  Agriculture, Forestry, Fishing and Hunting  sector
# 3     6  California    11  Agriculture, Forestry, Fishing and Hunting  sector
# 4     6  California    11  Agriculture, Forestry, Fishing and Hunting  sector
#
#   OCC_CODE                        OCC_TITLE   O_GROUP TOT_EMP EMP_PRSE  ...  \
# 0  00-0000                  All Occupations     total  231340        0  ...
# 1  11-0000           Management Occupations     major    3560      5.5  ...
# 2  11-1011                 Chief Executives  detailed      30     17.1  ...
# 3  11-1021  General and Operations Managers  detailed    1340      8.6  ...
# 4  11-2022                   Sales Managers  detailed     110     12.9  ...
#
# ...

# %%
df_california = df_california.loc[df_california["O_GROUP"]=="detailed"]

# %% [markdown]
# ## Build occupation matrix

# %%
df_nat = df_occupations_det.loc[(df_occupations_det["AREA"] == 99)].copy()

# %%
# Some NAs in tot_emp and in average wage
bad = df_nat.loc[pd.to_numeric(df_nat["TOT_EMP"], errors="coerce").isna(), ["TOT_EMP"]].drop_duplicates()
print("Non-numeric TOT_EMP examples:\n", bad)
bad = df_nat.loc[pd.to_numeric(df_nat["H_MEAN"], errors="coerce").isna(), ["H_MEAN"]].drop_duplicates()
print("Non-numeric H_MEAN examples:\n", bad)
# Out:
# Non-numeric TOT_EMP examples:
#      TOT_EMP
# 987      **
# Non-numeric H_MEAN examples:
#       H_MEAN
# 2         *
# 4389      #

# %%
SPECIAL_NA = {"**": np.nan, "*": np.nan, "#": np.nan}

def clean_bls_numeric(df, cols):
    df = df.copy()
    for c in cols:
        if c in df.columns:
            df[c] = (df[c]
                     .astype(str).str.strip()
                     .replace(SPECIAL_NA)
                    )
            df[c] = pd.to_numeric(df[c], errors="coerce")  # keeps NaN for anything non-numeric
    return df

df_nat = clean_bls_numeric(df_nat, ["TOT_EMP", "H_MEAN", "A_MEAN", "JOBS_1000", "LOC_QUOTIENT", "PCT_TOTAL"])
df_california = clean_bls_numeric(df_california, ["TOT_EMP", "H_MEAN", "A_MEAN", "JOBS_1000", "LOC_QUOTIENT", "PCT_TOTAL"])

# %%
def build_naics_soc_matrix(long_df, aggregation):
    # pick what to aggregate
    long_df = long_df.loc[long_df["O_GROUP"]==aggregation]
    agg = (long_df.groupby(["AREA", "AREA_TITLE",  "NAICS_CLEAN", "naics_len","OCC_CODE", "OCC_TITLE"], as_index=False)
           .agg(
               TOT_EMP=("TOT_EMP", "sum"),
               H_MEAN=("H_MEAN", "mean"),
               N_ROWS=("OCC_CODE", "size")
           ))
    # Wide matrix (NAICS x SOC) using TOT_EMP
    mat = agg.pivot_table(index=["NAICS_CLEAN", "naics_len"], columns="OCC_CODE",values="TOT_EMP",aggfunc="sum",fill_value=0)
    return agg, mat

nat_agg, nat_matrix = build_naics_soc_matrix(df_nat, "detailed")
cal_agg, cal_matrix = build_naics_soc_matrix(df_california, "detailed")
cal_agg.head()
# Out:
#    AREA  AREA_TITLE NAICS_CLEAN  naics_len OCC_CODE  \
# 0     6  California          11          2  11-1011
# 1     6  California          11          2  11-1021
# 2     6  California          11          2  11-2022
# 3     6  California          11          2  11-3012
# 4     6  California          11          2  11-3013
#
#                           OCC_TITLE  TOT_EMP  H_MEAN  N_ROWS
# 0                  Chief Executives     30.0  154.93       1
# 1   General and Operations Managers   1340.0   60.44       1
# 2                    Sales Managers    110.0   89.09       1
# 3  Administrative Services Managers    100.0   55.09       1
# 4               Facilities Managers    100.0   54.02       1

# %% [markdown]
# ### Obtain California Totals
#
# As we don't have the metro employment data by SOC & NAICS, we will take the share of California and apply them to SD.

# %%
# 1) Build P_CA(NAICS | SOC)
ca_soc_tot = (cal_agg.groupby("OCC_CODE", as_index=False)["TOT_EMP"].sum().rename(columns={"TOT_EMP":"TOT_CA_SOC"}))
ca_shares = cal_agg.merge(ca_soc_tot, on="OCC_CODE", how="left")
ca_shares["p_naics_given_soc"] = np.where(ca_shares["TOT_CA_SOC"] > 0, ca_shares["TOT_EMP"] / ca_shares["TOT_CA_SOC"],np.nan)
ca_shares.head()
# Out:
#    AREA  AREA_TITLE NAICS_CLEAN  naics_len OCC_CODE  \
# 0     6  California          11          2  11-1011
# 1     6  California          11          2  11-1021
# 2     6  California          11          2  11-2022
# 3     6  California          11          2  11-3012
# 4     6  California          11          2  11-3013
#
#                           OCC_TITLE  TOT_EMP  H_MEAN  N_ROWS  TOT_CA_SOC  \
# 0                  Chief Executives     30.0  154.93       1    117750.0
# 1   General and Operations Managers   1340.0   60.44       1    872170.0
# 2                    Sales Managers    110.0   89.09       1    349560.0
# 3  Administrative Services Managers    100.0   55.09       1    114930.0
# 4               Facilities Managers    100.0   54.02       1     54140.0
#
#    p_naics_given_soc
# 0           0.000255
# 1           0.001536
# 2           0.000315
# 3           0.000870
# 4           0.001847

# %%
# 2) Apply to SD SOC totals
df_sd = df_occupations_det.loc[(df_occupations_det["AREA"]==41740) & (df_occupations_det["O_GROUP"]=="detailed")].copy()
df_sd = clean_bls_numeric(df_sd, ["TOT_EMP", "H_MEAN", "A_MEAN", "JOBS_1000", "LOC_QUOTIENT", "PCT_TOTAL"])
sd_hat = ca_shares.merge(df_sd[["OCC_CODE", "O_GROUP","TOT_EMP", "H_MEAN"]], on="OCC_CODE", how="inner")
sd_hat.rename(columns={"TOT_EMP_y": "TOT_EMP_SD", "H_MEAN_y":"H_MEAN_SD"}, inplace=True)
sd_hat["TOT_EMP_SD_hat"] = sd_hat["TOT_EMP_SD"] * sd_hat["p_naics_given_soc"]
sd_naics_soc = (sd_hat.groupby(["NAICS_CLEAN", "naics_len","OCC_CODE","OCC_TITLE","O_GROUP", "H_MEAN_SD"], dropna=False,as_index=False)["TOT_EMP_SD_hat"].sum())
sd_naics_soc.head()
# Out:
#   NAICS_CLEAN  naics_len OCC_CODE                         OCC_TITLE   O_GROUP  \
# 0          11          2  11-1011                  Chief Executives  detailed
# 1          11          2  11-1021   General and Operations Managers  detailed
# 2          11          2  11-2022                    Sales Managers  detailed
# 3          11          2  11-3012  Administrative Services Managers  detailed
# 4          11          2  11-3013               Facilities Managers  detailed
#
#    H_MEAN_SD  TOT_EMP_SD_hat
# 0   135.4900          0.8306
# 1        NaN         38.2870
# 2    70.2900          2.5961
# 3    62.6500          2.3841
# 4    57.5900          3.0846

# %%
df_sd["TOT_EMP"].sum()
# Out:
# 1503720.0

# %%
sd_naics_soc["AREA"] = 41740
sd_naics_soc["AREA_TITLE"] = "San Diego-Carlsbad, CA"

# %%
#quality check to see that we did everything right and that the sum of the estimates by SOC equals the total employment in SD according to BLS
check = (sd_naics_soc.groupby("OCC_CODE")["TOT_EMP_SD_hat"].sum().reset_index().merge(df_sd[["OCC_CODE", "TOT_EMP"]], on="OCC_CODE", how="left"))
check["diff"] = round(check["TOT_EMP_SD_hat"] - check["TOT_EMP"], 2).abs()
check[["OCC_CODE", "TOT_EMP_SD_hat", "TOT_EMP", "diff"]].sort_values(by= "diff", ascending= False)
# Out:
#     OCC_CODE  TOT_EMP_SD_hat  TOT_EMP  diff
# 560  49-9092             0.0     90.0  90.0
# 0    11-1011          3260.0   3260.0   0.0
# 452  43-4121           830.0    830.0   0.0
# 445  43-4031           970.0    970.0   0.0
# 446  43-4041            50.0     50.0   0.0
# ..       ...             ...      ...   ...
# 502  47-2132             0.0      NaN   NaN
# 512  47-3012             0.0      NaN   NaN
# 515  47-3015             0.0      NaN   NaN
# 533  49-2096             0.0      NaN   NaN
# 556  49-9063             0.0      NaN   NaN
#
# [673 rows x 4 columns]

# %%
# Manually distribute "49-9092" as it appears without data in California byt it has in SD
sd_total = (df_sd.loc[(df_sd["OCC_CODE"] == "49-9092") & (df_sd["O_GROUP"] == "detailed"), "TOT_EMP"]
              .pipe(pd.to_numeric, errors="coerce")
              .sum(min_count=1))

mask_occ = sd_naics_soc["OCC_CODE"].eq("49-9092")
sd_naics_soc.loc[mask_occ, "naics_len"] = sd_naics_soc.loc[mask_occ, "NAICS_CLEAN"].astype(str).str.len()

half = sd_total / 2

def sector_leaf_codes(df, sector_prefix):
    s = df.loc[mask_occ, "NAICS_CLEAN"]
    in_sector = s.str.startswith(sector_prefix)
    if not in_sector.any():
        return []
    max_len = s[in_sector].str.len().max()
    leaves = s[in_sector & s.str.len().eq(max_len)].unique().tolist()
    return leaves

for sec in ["48", "56"]:
    leaves = sector_leaf_codes(sd_naics_soc, sec)
    alloc = half / len(leaves)
    sd_naics_soc.loc[mask_occ & sd_naics_soc["NAICS_CLEAN"].isin(leaves), "TOT_EMP_SD_hat"] = alloc

base = sd_naics_soc.loc[mask_occ, ["NAICS_CLEAN", "TOT_EMP_SD_hat"]].copy()

codes = sd_naics_soc.loc[mask_occ, "NAICS_CLEAN"].tolist()
for code in codes:
    sd_naics_soc.loc[mask_occ & sd_naics_soc["NAICS_CLEAN"].eq(code), "TOT_EMP_SD_hat"] = base.loc[
        base["NAICS_CLEAN"].str.startswith(code), "TOT_EMP_SD_hat"].sum()

sd_naics_soc.loc[sd_naics_soc.OCC_CODE=="49-9092"]
# Out:
#       NAICS_CLEAN  naics_len OCC_CODE          OCC_TITLE   O_GROUP  H_MEAN_SD  \
# 12157        4849          4  49-9092  Commercial Divers  detailed       38.3
# 12464         488          3  49-9092  Commercial Divers  detailed       38.3
# 12597        4883          4  49-9092  Commercial Divers  detailed       38.3
# 20041          56          2  49-9092  Commercial Divers  detailed       38.3
# 20428         561          3  49-9092  Commercial Divers  detailed       38.3
# 21731        5619          4  49-9092  Commercial Divers  detailed       38.3
#
#        TOT_EMP_SD_hat   AREA              AREA_TITLE
# 12157            22.5  41740  San Diego-Carlsbad, CA
# 12464            22.5  41740  San Diego-Carlsbad, CA
# 12597            22.5  41740  San Diego-Carlsbad, CA
# 20041            45.0  41740  San Diego-Carlsbad, CA
# 20428            45.0  41740  San Diego-Carlsbad, CA
# 21731            45.0  41740  San Diego-Carlsbad, CA

# %%
sd_naics_soc.rename(columns={"TOT_EMP_SD_hat": "TOT_EMP", "H_MEAN_SD":"H_MEAN"}, inplace=True)
sd_naics_soc["TOT_EMP"] = round(sd_naics_soc["TOT_EMP"])
sd_agg, sd_matrix = build_naics_soc_matrix(sd_naics_soc, "detailed")

# %% [markdown]
# ## Education

# %%
education_entry_level = pd.read_excel(DATASETS_OCCUPATIONS +"education_2024.xlsx", sheet_name= "educ_list")
education_entry_level.rename(columns={"OEWS May 2024 Code": "OCC_CODE", "OEWS May 2024 Title": "OCC_TITLE","Typical entry-level educational requirement": "ENTRY_LEVEL"}, inplace=True)
education_entry_level.head()
# Out:
#   OCC_CODE                            OCC_TITLE        ENTRY_LEVEL
# 0  11-1011                     Chief Executives  Bachelor's degree
# 1  11-1021      General and Operations Managers  Bachelor's degree
# 2  11-1031                          Legislators  Bachelor's degree
# 3  11-2011  Advertising and Promotions Managers  Bachelor's degree
# 4  11-2021                   Marketing Managers  Bachelor's degree

# %% [markdown]
# ### Critical Occupations

# %%
ED_OK = {
    "Bachelor's degree",
    "Master's degree",
    "Associate's degree",
    "Doctoral or professional degree"
}

# 1) Keep only the "all NAICS" row (naics_len==0 / NAICS_CLEAN=='000000')
nat_base = nat_agg.loc[nat_agg["naics_len"].eq(0), ["OCC_CODE", "OCC_TITLE", "TOT_EMP", "H_MEAN"]].copy()
nat_base = nat_base.rename(columns={"TOT_EMP": "TOT_EMP_US", "H_MEAN": "H_MEAN_US"})

nat_base = (nat_base.groupby(["OCC_CODE", "OCC_TITLE"], as_index=False)
          .apply(lambda g: pd.Series({
              "TOT_EMP_US": g["TOT_EMP_US"].sum(min_count=1),
              "H_MEAN_US": (np.average(g.loc[g["H_MEAN_US"].notna() & (g["TOT_EMP_US"]>0), "H_MEAN_US"],
                                       weights=g.loc[g["H_MEAN_US"].notna() & (g["TOT_EMP_US"]>0), "TOT_EMP_US"])
                            if ((g["H_MEAN_US"].notna() & (g["TOT_EMP_US"]>0)).any()) else np.nan)
          }))
          .reset_index(drop=True))
nat_base
# Out:
#     OCC_CODE                                  OCC_TITLE  TOT_EMP_US  \
# 0    11-1011                           Chief Executives    462090.0
# 1    11-1021            General and Operations Managers   7333160.0
# 2    11-1031                                Legislators     79530.0
# 3    11-2011        Advertising and Promotions Managers     42590.0
# 4    11-2021                         Marketing Managers    776120.0
# ..       ...                                        ...         ...
# 826  53-7072    Pump Operators, Except Wellhead Pumpers     25610.0
# 827  53-7073                           Wellhead Pumpers     34700.0
# 828  53-7081  Refuse and Recyclable Material Collectors    322800.0
# 829  53-7121          Tank Car, Truck, and Ship Loaders     21800.0
# 830  53-7199         Material Moving Workers, All Other     52400.0
#
#       H_MEAN_US
# 0    122.773096
# 1     64.042869
# 2           NaN
# 3     71.614724
# 4     82.271482
# ..          ...
# 826   29.758665
# ...

# %%
# 2) For San Diego, aggregate across NAICS
sd_base = sd_agg[["OCC_CODE", "OCC_TITLE", "TOT_EMP", "H_MEAN"]].copy()
sd_base["TOT_EMP"] = pd.to_numeric(sd_base["TOT_EMP"], errors="coerce")
sd_base["H_MEAN"] = pd.to_numeric(sd_base["H_MEAN"], errors="coerce")

sd_occ = (sd_base.groupby(["OCC_CODE", "OCC_TITLE"], as_index=False)
          .apply(lambda g: pd.Series({
              "TOT_EMP_SD": g["TOT_EMP"].sum(min_count=1),
              "H_MEAN_SD": (np.average(g.loc[g["H_MEAN"].notna() & (g["TOT_EMP"]>0), "H_MEAN"],
                                       weights=g.loc[g["H_MEAN"].notna() & (g["TOT_EMP"]>0), "TOT_EMP"])
                            if ((g["H_MEAN"].notna() & (g["TOT_EMP"]>0)).any()) else np.nan)}))
          .reset_index(drop=True))
sd_occ
# Out:
#     OCC_CODE                                  OCC_TITLE  TOT_EMP_SD  H_MEAN_SD
# 0    11-1011                           Chief Executives      3254.0     135.49
# 1    11-1021            General and Operations Managers     24919.0        NaN
# 2    11-1031                                Legislators       210.0        NaN
# 3    11-2011        Advertising and Promotions Managers       159.0      74.17
# 4    11-2021                         Marketing Managers      4393.0      93.41
# ..       ...                                        ...         ...        ...
# 668  53-7063             Machine Feeders and Offbearers       329.0      19.40
# 669  53-7064                Packers and Packagers, Hand      5162.0      18.81
# 670  53-7065                 Stockers and Order Fillers     21023.0      20.47
# 671  53-7081  Refuse and Recyclable Material Collectors       949.0      31.76
# 672  53-7199         Material Moving Workers, All Other       967.0      18.56
#
# [673 rows x 4 columns]

# %%
# 3) Merge SD + US + education
crit = (sd_occ.merge(nat_base[["OCC_CODE", "TOT_EMP_US", "H_MEAN_US"]], on="OCC_CODE", how="left")
              .merge(education_entry_level[["OCC_CODE", "ENTRY_LEVEL"]], on="OCC_CODE", how="left"))
crit = crit.drop_duplicates()

# 4) Compute wage premium + apply rules
crit["wage_premium_sd_vs_us"] = crit["H_MEAN_SD"] / crit["H_MEAN_US"]
crit["is_edu_ok"] = crit["ENTRY_LEVEL"].isin(ED_OK)

# %%
# Create critical flag based on criteria
mask_crit = (crit["is_edu_ok"] &crit["H_MEAN_SD"].notna() & crit["H_MEAN_US"].notna() & (crit["H_MEAN_SD"] > crit["H_MEAN_US"]))
crit["critical_flag"] = mask_crit.map({True: "critical", False: "not_critical"})
crit = crit.sort_values(["critical_flag", "wage_premium_sd_vs_us", "TOT_EMP_SD"], ascending=[True, False, False])
crit.head(20)
# Out:
#     OCC_CODE                                          OCC_TITLE  TOT_EMP_SD  \
# 269  27-4032                             Film and Video Editors       351.0
# 254  27-3011        Broadcast Announcers and Radio Disc Jockeys       151.0
# 153  19-4043  Geological Technicians, Except Hydrologic Tech...       122.0
# 221  25-3011  Adult Basic Education, Adult Secondary Educati...       179.0
# 309  29-2033                     Nuclear Medicine Technologists        99.0
# 289  29-1141                                  Registered Nurses     27663.0
# 92   17-1022                                          Surveyors       361.0
# 282  29-1124                               Radiation Therapists       140.0
# 34   11-9161                     Emergency Management Directors        50.0
# 486  45-2011                            Agricultural Inspectors        81.0
# 283  29-1125                            Recreational Therapists        91.0
# ...

# %% [markdown]
# ## Link Defense NAICS

# %%
naics_in_soc = nat_agg[["NAICS_CLEAN", "naics_len"]].drop_duplicates()
naics_in_soc.head()
# Out:
#      NAICS_CLEAN  naics_len
# 0         000000          0
# 831       000001          0
# 1648          11          2
# 1799         113          3
# 1841        1133          4

# %%
m6 = sectors_6digits.drop_duplicates("NAICS_6")[["NAICS_6", "Strategic Sector"]]
naics_in_soc = naics_in_soc.merge(m6, left_on="NAICS_CLEAN", right_on="NAICS_6", how="left")
naics_in_soc.drop(columns=["NAICS_6"], inplace=True)

# --- 2) if not matched, try 5 digits ---
naics_in_soc["naics5"] = naics_in_soc["NAICS_CLEAN"].str[:5]
m5 = sectors_6digits.drop_duplicates("NAICS_5")[["NAICS_5", "Strategic Sector"]].rename(columns={"Strategic Sector":"sector_5"})
naics_in_soc = naics_in_soc.merge(m5, left_on="naics5", right_on="NAICS_5", how="left")
naics_in_soc.drop(columns=["NAICS_5"], inplace=True)
naics_in_soc["Strategic Sector"] = naics_in_soc["Strategic Sector"].fillna(naics_in_soc["sector_5"])
naics_in_soc.drop(columns=["sector_5"], inplace=True)

# --- 3) if still not matched, try 4 digits ---
naics_in_soc["naics4"] = naics_in_soc["NAICS_CLEAN"].str[:4]
m4 = sectors_6digits.drop_duplicates("NAICS_4")[["NAICS_4", "Strategic Sector"]].rename(columns={"Strategic Sector":"sector_4"})
naics_in_soc = naics_in_soc.merge(m4, left_on="naics4", right_on="NAICS_4", how="left")
naics_in_soc.drop(columns=["NAICS_4"], inplace=True)
naics_in_soc["Strategic Sector"] = naics_in_soc["Strategic Sector"].fillna(naics_in_soc["sector_4"])
naics_in_soc.drop(columns=["sector_4"], inplace=True)

naics_in_soc["is_strategic"] = naics_in_soc["Strategic Sector"].notna()

# %%
naics_to_sector = naics_in_soc.loc[naics_in_soc["is_strategic"] == True]

# %%
# df_states = pd.read_excel(DATASETS_OCCUPATIONS + "oes_research_2023_allsectors.xlsx")
# df_states["NAICS_CLEAN"] = df_states["NAICS_CLEAN"].astype(str).str.upper().str.replace(r"[^0-9A-Z]", "", regex=True)
# level_map = {"cross-industry": 0,"cross-industry, ownership": 0,"sector": 2,"3-digit": 3,"3-digit, ownership": 3,"4-digit": 4,"4-digit, ownership": 4,
#     "5-digit": 5,"6-digit": 6,}
# df_states["i_group_clean"] = df_states["I_GROUP"].astype(str).str.strip().str.lower()
# df_states["naics_len"] = df_states["i_group_clean"].map(level_map)
# df_states_strategic_sectors = df_states.loc[df_states["NAICS_CLEAN"].isin(naics_to_sector["NAICS_CLEAN"])]
# df_states.head()

# %% [markdown]
# ## Analysis defense occupations

# %%
nat_agg = nat_agg.merge(crit[["OCC_CODE", "critical_flag", "ENTRY_LEVEL", "wage_premium_sd_vs_us"]], left_on="OCC_CODE", right_on="OCC_CODE", how="left")
sd_agg = sd_agg.merge(crit[["OCC_CODE", "critical_flag", "ENTRY_LEVEL", "wage_premium_sd_vs_us"]], left_on="OCC_CODE", right_on="OCC_CODE", how="left")

# %%
nat_agg["TOT_EMP"] = pd.to_numeric(nat_agg["TOT_EMP"], errors="coerce")
nat_agg["H_MEAN"] = pd.to_numeric(nat_agg["H_MEAN"], errors="coerce")
nat_agg["wage_premium_sd_vs_us"] = pd.to_numeric(nat_agg["wage_premium_sd_vs_us"], errors="coerce")
nat_agg = nat_agg[nat_agg["TOT_EMP"].notna() & (nat_agg["TOT_EMP"] > 0)]

# %%
sd_agg["TOT_EMP"] = pd.to_numeric(sd_agg["TOT_EMP"], errors="coerce")
sd_agg["H_MEAN"] = pd.to_numeric(sd_agg["H_MEAN"], errors="coerce")
sd_agg["wage_premium_sd_vs_us"] = pd.to_numeric(sd_agg["wage_premium_sd_vs_us"], errors="coerce")
sd_agg = sd_agg[sd_agg["TOT_EMP"].notna() & (sd_agg["TOT_EMP"] > 0)]

# %%
data_labor_sd = data_labor.loc[data_labor["metropolitan statistical area/micropolitan statistical area"] == "41740"]

# %%
data_labor["NAICS2017_4"] = data_labor["NAICS2017"].str[:4]
data_labor["NAICS2017_3"] = data_labor["NAICS2017"].str[:3]

# %%
# Do this calculation at national level
total_values = data_labor.loc[data_labor["NAICS2017_4"].isin(["3364", "3366", "3369", "332"])].groupby("NAICS2017_4", as_index=False)["EMP"].sum()
total_values.rename(columns={"EMP": "TOTAL_EMP", "NAICS2017_4": "NAICS_TOTAL"}, inplace=True)
total_temp = data_labor.loc[data_labor["NAICS2017_3"].isin(["3364", "3366", "3369", "332"])].groupby("NAICS2017_3", as_index=False)["EMP"].sum()
total_temp.rename(columns={"EMP": "TOTAL_EMP", "NAICS2017_3": "NAICS_TOTAL"}, inplace=True)
total_values = pd.concat([total_values, total_temp], ignore_index=True)

# %%
interest_naics =["336992","336411","336412","336413","336414","336415","336419","336611","336612","332992","332993","332994"]
total_values_6 = data_labor.loc[data_labor["NAICS2017"].isin(interest_naics)].groupby(["NAICS2017", "NAICS2017_3", "NAICS2017_4"], as_index=False)["EMP"].sum()
total_values_6 = total_values_6.merge(total_values, left_on="NAICS2017_4", right_on="NAICS_TOTAL", how="left").drop(columns=["NAICS_TOTAL"]).merge(total_values, left_on="NAICS2017_3", right_on="NAICS_TOTAL", how="left", suffixes=("_4digit", "_3digit")).drop(columns=["NAICS_TOTAL"])
total_values_6["TOTAL_EMP"] = total_values_6["TOTAL_EMP_4digit"].combine_first(total_values_6["TOTAL_EMP_3digit"])
total_values_6.drop(columns=["TOTAL_EMP_4digit", "TOTAL_EMP_3digit"], inplace=True)
total_values_6
# Out:
#    NAICS2017 NAICS2017_3 NAICS2017_4     EMP  TOTAL_EMP
# 0     332992         332        3329    4044  1047116.0
# 1     332994         332        3329   17003  1047116.0
# 2     336411         336        3364  142435   303947.0
# 3     336412         336        3364   53062   303947.0
# 4     336413         336        3364   86716   303947.0
# 5     336414         336        3364    8658   303947.0
# 6     336415         336        3364   10840   303947.0
# 7     336419         336        3364    2236   303947.0
# 8     336611         336        3366   74580   104902.0
# 9     336612         336        3366   30322   104902.0
# 10    336992         336        3369    1926    14232.0

# %%
# 3364  and 3366 are not needed to weight, they eq totals
total_values_6
# Out:
#    NAICS2017 NAICS2017_3 NAICS2017_4     EMP  TOTAL_EMP
# 0     332992         332        3329    4044  1047116.0
# 1     332994         332        3329   17003  1047116.0
# 2     336411         336        3364  142435   303947.0
# 3     336412         336        3364   53062   303947.0
# 4     336413         336        3364   86716   303947.0
# 5     336414         336        3364    8658   303947.0
# 6     336415         336        3364   10840   303947.0
# 7     336419         336        3364    2236   303947.0
# 8     336611         336        3366   74580   104902.0
# 9     336612         336        3366   30322   104902.0
# 10    336992         336        3369    1926    14232.0

# %%
total_values_6["share"] = total_values_6["EMP"] / total_values_6["TOTAL_EMP"]
total_values_6["NAICS_CLEAN"] = np.where(total_values_6["NAICS2017_3"].eq("332"),
                             total_values_6["NAICS2017_3"],   # "332"
                             total_values_6["NAICS2017_4"])   # e.g. "3364"
total_values_6 = total_values_6.loc[total_values_6["NAICS_CLEAN"].isin(["332", "3369"])]
total_values_6.drop(columns=["NAICS2017_3", "NAICS2017_4"], inplace=True)
total_values_6.head()
# Out:
# <ipython-input-45-ac1db9906b66>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_values_6.drop(columns=["NAICS2017_3", "NAICS2017_4"], inplace=True)
#    NAICS2017    EMP  TOTAL_EMP     share NAICS_CLEAN
# 0     332992   4044  1047116.0  0.003862         332
# 1     332994  17003  1047116.0  0.016238         332
# 10    336992   1926    14232.0  0.135329        3369

# %%
nat_agg_defense = nat_agg.merge(total_values_6, how="left", on="NAICS_CLEAN")
nat_agg_defense["share"] = nat_agg_defense["share"].fillna(0.0)  # industries not in weights => 0

# %%
nat_agg_defense.shape
# Out:
# (70622, 16)

# %%
nat_agg_defense.drop_duplicates(subset=["AREA","NAICS_CLEAN", "OCC_CODE"], inplace=True)
nat_agg_defense.shape
# Out:
# (69380, 16)

# %%
sd_agg.rename(columns={"TOT_EMP": "TOT_EMP_SD", "H_MEAN": "H_MEAN_SD"}, inplace=True)

# %%
sd_agg["TOT_EMP_SD"].sum()
# Out:
# 1503825.0

# %%
nat_agg_defense = nat_agg_defense.merge(sd_agg[["NAICS_CLEAN","OCC_CODE", "TOT_EMP_SD", "H_MEAN_SD"]], on=["NAICS_CLEAN","OCC_CODE"], how="left")

# %%
mask_split = nat_agg_defense["share"] > 0
to_split = nat_agg_defense.loc[mask_split].copy()
no_split = nat_agg_defense.loc[~mask_split].copy()

# %%
print("Total EMP in no-split part (SD):", no_split["TOT_EMP_SD"].sum())
# Out:
# Total EMP in no-split part (SD): 1497347.0

# %%
# Defense part
def_part = to_split.copy()
def_part["industry_part"] = "defense_part"
def_part["EMP_FINAL_US"] = round(def_part["TOT_EMP"] * def_part["share"])
def_part["EMP_FINAL_SD"] = round(def_part["TOT_EMP_SD"] * def_part["share"])
print("Total EMP in defense part (SD):", def_part["TOT_EMP_SD"].sum())
print("Total EMP in defense part (SD):", def_part["EMP_FINAL_SD"].sum())

# Rest part
rest_part = to_split.copy()
rest_part["industry_part"] = "non_defense"
rest_part["EMP_FINAL_US"] = rest_part["TOT_EMP"] * (1 - rest_part["share"])
rest_part["EMP_FINAL_SD"] = rest_part["TOT_EMP_SD"] * (1 - rest_part["share"])
print("Total EMP in rest part (SD):", rest_part["TOT_EMP_SD"].sum())
print("Total EMP in rest part (SD):", rest_part["EMP_FINAL_SD"].sum())

# For industries not split, keep as-is
no_split["industry_part"] = "non_defense"
print("Total EMP in no-split part (SD):", no_split["TOT_EMP_SD"].sum())
#print("Total EMP in no-split part (US):", no_split["EMP_FINAL_US"].sum())
DEFENSE_FULL = {"3364", "3366"}
no_split.loc[no_split["NAICS_CLEAN"].astype(str).isin(DEFENSE_FULL), "industry_part"] = "defense_part"
# IMPORTANT have to do this because if not we're duplicating things
#no_split = no_split.loc[no_split["naics_len"].eq(4)]
no_split["EMP_FINAL_US"] = no_split["TOT_EMP"]
no_split["EMP_FINAL_SD"] = no_split["TOT_EMP_SD"]
print("Total EMP in no-split part (SD):", no_split["EMP_FINAL_SD"].sum())
#print("Total EMP in no-split part (US):", no_split["EMP_FINAL_US"].sum())

# Combine
df_split = pd.concat([no_split, def_part, rest_part], ignore_index=True)
# Out:
# Total EMP in defense part (SD): 3437.0
# Total EMP in defense part (SD): 9.0
# Total EMP in rest part (SD): 3437.0
# Total EMP in rest part (SD): 3415.5752396366006
# Total EMP in no-split part (SD): 1497347.0
# Total EMP in no-split part (SD): 1497347.0

# %%
df_split.rename(columns={"TOT_EMP": "TOT_EMP_US", "H_MEAN": "H_MEAN_US", "EMP_FINAL": "EMP_FINAL_US"}, inplace=True)

# %%
df_split.loc[(df_split["NAICS_CLEAN"].isin(["332", "3369", "3364", "3366"]))& (df_split["industry_part"]=="defense_part")].groupby("NAICS_CLEAN")["EMP_FINAL_US"].sum()
# Out:
# NAICS_CLEAN
# 332       5561.0
# 3364    548430.0
# 3366    138680.0
# 3369      9958.0
# Name: EMP_FINAL_US, dtype: float64

# %%
df_split.loc[(df_split["NAICS_CLEAN"].isin(["332", "3369", "3364", "3366"]))& (df_split["industry_part"]=="defense_part")].groupby("NAICS_CLEAN")["EMP_FINAL_SD"].sum()
# Out:
# NAICS_CLEAN
# 332        5.0
# 3364    2499.0
# 3366     316.0
# 3369       4.0
# Name: EMP_FINAL_SD, dtype: float64

# %%
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

# %%
df_split.groupby("industry_part")["EMP_FINAL_US"].sum()
# Out:
# industry_part
# defense_part       702,629.00
# non_defense    861,841,618.24
# Name: EMP_FINAL_US, dtype: float64

# %%
df_split.groupby("industry_part")["EMP_FINAL_SD"].sum()
# Out:
# industry_part
# defense_part       2,824.00
# non_defense    1,497,947.58
# Name: EMP_FINAL_SD, dtype: float64

# %%
df_split.groupby("industry_part")["TOT_EMP_SD"].sum()
# Out:
# industry_part
# defense_part       6,252.00
# non_defense    1,497,969.00
# Name: TOT_EMP_SD, dtype: float64

# %%
def weighted_mean(x, w):
    x, w = np.array(x), np.array(w)
    m = np.isfinite(x) & np.isfinite(w)
    if m.sum() == 0:
        return np.nan
    return np.sum(x[m] * w[m]) / np.sum(w[m])

def concentration_metrics(sub, occ_col="OCC_CODE", emp_col="TOT_EMP_US"):
    """Returns HHI and top-10 share of employment across occupations."""
    g = (sub.groupby(occ_col, as_index=False)[emp_col].sum()
           .sort_values(emp_col, ascending=False))
    total = g[emp_col].sum()
    if total <= 0:
        return {"hhi": np.nan, "top10_share": np.nan, "n_occ": 0}
    shares = (g[emp_col] / total).values
    hhi = np.sum(shares ** 2)
    top10_share = shares[:10].sum()
    return {"hhi": hhi, "top10_share": top10_share, "n_occ": g.shape[0]}

# %%
df_split.loc[df_split["naics_len"].eq(2)]["EMP_FINAL_SD"].sum()
# Out:
# 476787.0

# %%
df_split.loc[df_split["naics_len"].eq(2)]["EMP_FINAL_US"].sum()
# Out:
# 154806260.0

# %%
summary_rows = []
for grp, sub in df_split.groupby("industry_part"):
    # wage: employment-weighted mean (more meaningful than simple average)
    wage_wmean = weighted_mean(sub["H_MEAN_US"], sub["EMP_FINAL_US"])
    # critical share (employment-weighted)
    total_emp = sub["EMP_FINAL_US"].sum()
    crit_emp = sub.loc[sub["critical_flag"].eq("critical"), "EMP_FINAL_US"].sum()
    crit_share = crit_emp / total_emp if total_emp > 0 else np.nan

    # concentration
    conc = concentration_metrics(sub)

    summary_rows.append({
        "group": grp,
        "total_emp": total_emp,
        "n_occupations": conc["n_occ"],
        "wage_mean_weighted": wage_wmean,
        "critical_emp_share": crit_share,
        "hhi_occ_concentration": conc["hhi"],       # higher = more concentrated in few occupations
        "top10_occ_emp_share": conc["top10_share"], # share of employment in top 10 occupations
    })

summary = pd.DataFrame(summary_rows).sort_values("group")
summary
# Out:
#           group      total_emp  n_occupations  wage_mean_weighted  \
# 0  defense_part     702,629.00            282               45.43
# 1   non_defense 861,841,618.24            831               32.51
#
#    critical_emp_share  hhi_occ_concentration  top10_occ_emp_share
# 0                0.38                   0.02                 0.41
# 1                0.23                   0.01                 0.20

# %%
summary_rows = []
for grp, sub in df_split.groupby("industry_part"):
    # wage: employment-weighted mean (more meaningful than simple average)
    wage_wmean = weighted_mean(sub["H_MEAN_SD"], sub["EMP_FINAL_SD"])
    # critical share (employment-weighted)
    total_emp = sub["EMP_FINAL_SD"].sum()
    crit_emp = sub.loc[sub["critical_flag"].eq("critical"), "EMP_FINAL_SD"].sum()
    crit_share = crit_emp / total_emp if total_emp > 0 else np.nan

    # concentration
    conc = concentration_metrics(sub)

    summary_rows.append({
        "group": grp,
        "total_emp": total_emp,
        "n_occupations": conc["n_occ"],
        "wage_mean_weighted": wage_wmean,
        "critical_emp_share": crit_share,
        "hhi_occ_concentration": conc["hhi"],       # higher = more concentrated in few occupations
        "top10_occ_emp_share": conc["top10_share"], # share of employment in top 10 occupations
    })

summary = pd.DataFrame(summary_rows).sort_values("group")
summary
# Out:
#           group    total_emp  n_occupations  wage_mean_weighted  \
# 0  defense_part     2,824.00            282               46.53
# 1   non_defense 1,497,947.58            831               36.02
#
#    critical_emp_share  hhi_occ_concentration  top10_occ_emp_share
# 0                0.47                   0.02                 0.41
# 1                0.27                   0.01                 0.20

# %%
edu_mix = (df_split.groupby(["industry_part", "ENTRY_LEVEL"], as_index=False)["EMP_FINAL_US"]
             .sum())
edu_mix["share_emp"] = edu_mix["EMP_FINAL_US"] / edu_mix.groupby("industry_part")["EMP_FINAL_US"].transform("sum")
edu_pivot = edu_mix.pivot(index="ENTRY_LEVEL", columns="industry_part", values="share_emp").fillna(0)
print(edu_pivot)

# Plot education shares
plt.figure(figsize=(10, 6))
ax = edu_pivot.plot(kind="bar")
ax.set_ylabel("Share of employment")
ax.set_xlabel("Entry-level education")
ax.set_title("Education mix: Defense-related vs other industries (SD)")
plt.show()
# Out:
# industry_part                      defense_part  non_defense
# ENTRY_LEVEL
# Associate's degree                         0.03         0.02
# Bachelor's degree                          0.42         0.26
# Doctoral or professional degree            0.00         0.03
# High school diploma or equivalent          0.47         0.36
# Master's degree                            0.00         0.03
# No formal educational credential           0.02         0.21
# Postsecondary nondegree award              0.06         0.06
# Some college, no degree                    0.01         0.03

# %%
wage_df = df_split[df_split["H_MEAN_US"].notna()].copy()
plt.figure()
wage_df.boxplot(column="H_MEAN_US", by="industry_part", grid=False)
plt.suptitle("")
plt.title("Hourly wage distribution by group (SD)")
plt.ylabel("H_MEAN (hourly wage)")
plt.xlabel("")
plt.show()

# %%
def top_occupations(sub,  emp_col="EMP_FINAL_US", wage_col="H_MEAN_US", n=15):
    g = (sub.groupby(["OCC_CODE", "OCC_TITLE"], as_index=False)[emp_col].sum()
           .sort_values(emp_col, ascending=False))
    
    g_wage = (sub.groupby(["OCC_CODE", "OCC_TITLE"])
                .apply(lambda d: weighted_mean(d[wage_col], d[emp_col]))
                .reset_index(name="H_MEAN_wavg"))

    # merge + shares
    g = g.merge(g_wage, on=["OCC_CODE", "OCC_TITLE"], how="left")
    g = g.sort_values(emp_col, ascending=False)
    g["share_emp"] = g[emp_col] / g[emp_col].sum()

    return g.head(n)

top_def = top_occupations(df_split[df_split["industry_part"].eq("defense_part")], n=20)
top_other = top_occupations(df_split[df_split["industry_part"].eq("non_defense")], n=20)

print("Top 15 defense-related occupations:")
top_def[["OCC_CODE", "OCC_TITLE", "EMP_FINAL_US", "H_MEAN_wavg", "share_emp"]]["H_MEAN_wavg"].mean()
# Out:
# <ipython-input-62-ff0b6b0cd645>:6: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sum(x[m] * w[m]) / np.sum(w[m])
# Top 15 defense-related occupations:
# 44.653036496792616

# %%
print("\nTop 15 other-industry occupations:")
top_other[["OCC_CODE", "OCC_TITLE", "EMP_FINAL_US", "H_MEAN_wavg", "share_emp"]]["H_MEAN_wavg"].mean()
# Out:
# Top 15 other-industry occupations:
# 27.004654846046023

# %%
df_split.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'NAICS_CLEAN', 'naics_len', 'OCC_CODE',
#        'OCC_TITLE', 'TOT_EMP_US', 'H_MEAN_US', 'N_ROWS', 'critical_flag',
#        'ENTRY_LEVEL', 'wage_premium_sd_vs_us', 'NAICS2017', 'EMP', 'TOTAL_EMP',
#        'share', 'TOT_EMP_SD', 'H_MEAN_SD', 'industry_part', 'EMP_FINAL_US',
#        'EMP_FINAL_SD'],
#       dtype='object')

# %%
def agg_by_occ(df, grp_name):
    g = (df.groupby(["OCC_CODE", "OCC_TITLE", "critical_flag", "ENTRY_LEVEL"], as_index=False)
           .agg(EMP_FINAL_SD=("EMP_FINAL_SD", "sum")))
    # weighted wage by occ
    w = (df.groupby(["OCC_CODE", "OCC_TITLE"])
           .apply(lambda d: weighted_mean(d["H_MEAN_SD"], d["EMP_FINAL_SD"]))
           .reset_index(name="H_MEAN_wavg"))
    g = g.merge(w, on=["OCC_CODE", "OCC_TITLE"], how="left")
    g = g.rename(columns={
        "EMP_FINAL_SD": f"emp_{grp_name}",
        "H_MEAN_wavg": f"wage_{grp_name}"
    })
    return g

def_df = df_split[df_split["industry_part"].eq("defense_part")].copy()
oth_df = df_split[df_split["industry_part"].eq("non_defense")].copy()

def_occ = agg_by_occ(def_df, "def")
oth_occ = agg_by_occ(oth_df, "oth")

occ_compare = def_occ.merge(oth_occ, on=["OCC_CODE", "OCC_TITLE"], how="outer")
occ_compare[["emp_def","emp_oth"]] = occ_compare[["emp_def","emp_oth"]].fillna(0)
# Out:
# <ipython-input-62-ff0b6b0cd645>:6: RuntimeWarning: invalid value encountered in double_scalars
#   return np.sum(x[m] * w[m]) / np.sum(w[m])

# %%
both = occ_compare[(occ_compare["emp_def"] > 0) & (occ_compare["emp_oth"] > 0)].copy()
both["wage_ratio_def_vs_oth"] = both["wage_def"] / both["wage_oth"]

# overall summary (employment-weighted)
def wmean_series(x, w):
    m = x.notna() & w.notna() & (w > 0)
    return (x[m] * w[m]).sum() / w[m].sum() if m.any() else np.nan

avg_ratio_weighted = wmean_series(both["wage_ratio_def_vs_oth"], both["emp_def"])
print("Employment-weighted wage ratio (def vs other) for overlapping occupations:", avg_ratio_weighted)

# top premiums (filter out tiny emp to avoid noise)
top_premium = both[both["emp_def"] >= 500].sort_values("wage_ratio_def_vs_oth", ascending=False).head(20)
top_discount = both[both["emp_def"] >= 500].sort_values("wage_ratio_def_vs_oth", ascending=True).head(20)

top_premium[["OCC_TITLE","emp_def","wage_def","wage_oth","wage_ratio_def_vs_oth"]]
# Out:
# Employment-weighted wage ratio (def vs other) for overlapping occupations: 1.0
# Empty DataFrame
# Columns: [OCC_TITLE, emp_def, wage_def, wage_oth, wage_ratio_def_vs_oth]
# Index: []

# %%
# Simple overlap metric by OCC_CODE
overlap = set(top_def["OCC_CODE"]).intersection(set(top_other["OCC_CODE"]))
overlap
# Out:
# {'15-1252'}

# %% [markdown]
# ### Location Quotients by Occupation

# %%
pd.set_option("display.float_format", lambda x: f"{x:,.4f}")

# %%
sd_df = sd_agg.loc[sd_agg["naics_len"].eq(4)].groupby(["OCC_CODE", "OCC_TITLE", "H_MEAN_SD"])["TOT_EMP_SD"].sum().reset_index()
sd_df["share_numerador"] = sd_df["TOT_EMP_SD"] / sd_df["TOT_EMP_SD"].sum()
sd_df.rename(columns={"TOT_EMP_SD": "TOT_EMP_SD"}, inplace=True)

# %%
sd_df.sort_values("share_numerador", ascending=False).head()
# Out:
#     OCC_CODE                            OCC_TITLE  H_MEAN_SD  TOT_EMP_SD  \
# 269  31-1120  Home Health and Personal Care Aides    17.5500 13,350.0000
# 312  35-3023        Fast Food and Counter Workers    18.3900 13,325.0000
# 359  41-2031                  Retail Salespersons    20.1600 10,268.0000
# 355  41-2011                             Cashiers    18.5000 10,256.0000
# 416  43-9061               Office Clerks, General    23.8800  8,980.0000
#
#      share_numerador
# 269           0.0308
# 312           0.0308
# 359           0.0237
# 355           0.0237
# 416           0.0207

# %%
nat_df = nat_agg.loc[nat_agg["naics_len"].eq(4)].groupby(["OCC_CODE", "OCC_TITLE"])["TOT_EMP"].sum().reset_index()
nat_df["share_denominador"] = nat_df["TOT_EMP"] / nat_df["TOT_EMP"].sum()
nat_df.rename(columns={"TOT_EMP": "TOT_EMP_NAT"}, inplace=True)

# %%
lq_df = nat_df.merge(sd_df[["OCC_CODE", "TOT_EMP_SD","H_MEAN_SD","share_numerador"]], on="OCC_CODE", how="left")
lq_df["LQ"] = lq_df["share_numerador"] / lq_df["share_denominador"]
lq_df.sort_values("LQ", ascending=False).head(20)
# Out:
#     OCC_CODE                                          OCC_TITLE  TOT_EMP_NAT  \
# 437  37-2019               Building Cleaning Workers, All Other   3,180.0000
# 668  49-9092                                  Commercial Divers   2,770.0000
# 176  21-1013                     Marriage and Family Therapists  66,650.0000
# 456  39-3099  Entertainment Attendants and Related Workers, ...   7,760.0000
# 828  53-7199                 Material Moving Workers, All Other  20,880.0000
# 100  17-2061                        Computer Hardware Engineers  75,000.0000
# 102  17-2072             Electronics Engineers, Except Computer  92,540.0000
# 72   15-1221       Computer and Information Research Scientists  39,110.0000
# 809  53-6041                                Traffic Technicians   6,950.0000
# 432  35-9099  Food Preparation and Serving Related Workers, ...  91,910.0000
# 806  53-6021                                 Parking Attendants 127,910.0000
# ...

# %%
lq_df.shape
# Out:
# (829, 8)

# %%
def_occ = def_occ.merge(lq_df[["OCC_CODE", "H_MEAN_SD","TOT_EMP_SD","LQ"]], on="OCC_CODE", how="left").sort_values("LQ", ascending=False)

# %%
def categorize_occ(occ_code, occ_title=""):
    code = str(occ_code) if pd.notna(occ_code) else ""
    title = str(occ_title).lower() if pd.notna(occ_title) else ""

    # --- SOC major-group style mapping by prefix
    # 15 = Computer & Mathematical, 17 = Architecture & Engineering, 19 = Life/Physical/Social Science
    if code.startswith(("15-", "17-", "19-")):
        return "Engineering & Digital"

    # 51 = Production, 49 = Installation/Maintenance/Repair, 53 = Transportation/Material Moving
    if code.startswith(("51-", "49-", "53-")):
        # optional keyword refinement: avionics/mechanics/MRO strongly fits here
        return "Advanced Manufacturing & MRO"

    # 11 = Management, 13 = Business/Financial, 23 = Legal, 27 = Arts/Design/Media,
    # 41 = Sales, 43 = Office/Admin, 33 = Protective Service, 37 = Building/Grounds
    if code.startswith(("11-", "13-", "23-", "27-", "41-", "43-", "33-", "37-")):
        return "Operations & Management"

    # 47 = Construction / trades
    if code.startswith("47-"):
        return "Advanced Manufacturing & MRO"

    # Keyword-based catch for any weird/missing SOC codes
    if any(k in title for k in ["engineer", "software", "data scientist", "programmer", "architect", "chemist", "scientist"]):
        return "Engineering & Digital"
    if any(k in title for k in ["mechanic", "technician", "assembler", "machinist", "welder", "operator", "fabricator", "maintenance", "mro", "avionics"]):
        return "Advanced Manufacturing & MRO"
    if any(k in title for k in ["manager", "director", "analyst", "logistic", "purchasing", "compliance", "sales", "planner", "clerk", "hr", "finance", "lawyer"]):
        return "Operations & Management"

    return "Other / Support"

# Add category column (leave everything else unchanged)
def_occ["CATEGORY"] = def_occ.apply(lambda r: categorize_occ(r["OCC_CODE"], r.get("OCC_TITLE","")), axis=1)
def_occ
# Out:
#     OCC_CODE                                          OCC_TITLE critical_flag  \
# 260  53-7199                 Material Moving Workers, All Other  not_critical
# 59   17-2061                        Computer Hardware Engineers      critical
# 61   17-2072             Electronics Engineers, Except Computer      critical
# 119  41-9099               Sales and Related Workers, All Other  not_critical
# 106  33-9099              Protective Service Workers, All Other  not_critical
# ..       ...                                                ...           ...
# 73   17-3021  Aerospace Engineering and Operations Technolog...  not_critical
# 96   27-1024                                  Graphic Designers  not_critical
# 154  47-3012                                Helpers--Carpenters  not_critical
# 157  47-3015  Helpers--Pipelayers, Plumbers, Pipefitters, an...  not_critical
# 242  53-2012                                  Commercial Pilots  not_critical
#
# ...

# %%
def_occ["is_specialized"] = def_occ["LQ"] >= 1

WEIGHT_COL = "emp_def"   # change to "emp_def" if needed
plot_df = def_occ.dropna(subset=["ENTRY_LEVEL", "is_specialized", WEIGHT_COL]).copy()

edu = (plot_df.groupby(["is_specialized", "ENTRY_LEVEL"], as_index=False)[WEIGHT_COL]
              .sum()
              .rename(columns={WEIGHT_COL: "emp"}))

edu["share"] = edu["emp"] / edu.groupby("is_specialized")["emp"].transform("sum")
pivot = (edu.pivot(index="ENTRY_LEVEL", columns="is_specialized", values="share")
           .fillna(0))
pivot.columns = ["Not specialized (LQ<1)", "Specialized (LQ≥1)"]  # False then True
edu_order = ["No formal educational credential", "High school diploma or equivalent", "Some college, no degree", "Postsecondary nondegree award",
    "Associate's degree", "Bachelor's degree", "Master's degree", "Doctoral or professional degree",]
pivot = pivot.reindex([x for x in edu_order if x in pivot.index] + [x for x in pivot.index if x not in edu_order])

x = np.arange(len(pivot.index))
width = 0.42

# %%
wrap_width = 13  # adjust: smaller = more line breaks
labels = [textwrap.fill(str(lbl), width=wrap_width) for lbl in pivot.index]

fig, ax = plt.subplots(figsize=(10, 5.5))
ax.bar(x - width/2, pivot["Specialized (LQ≥1)"], width, label="Specialized (LQ≥1)", color = "#6d9ebc")
ax.bar(x + width/2, pivot["Not specialized (LQ<1)"], width, label="Not specialized (LQ<1)", color = "#ffab40")
ax.set_ylabel("Share of employment")
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=0, ha="center")
ax.set_ylim(0, max(pivot.max()) * 1.2 if pivot.size else 1)
ax.legend()
sns.despine()
plt.show()

# %%
for cat, g in plot_df.groupby("CATEGORY"):
    edu_cat = (g.groupby(["is_specialized", "ENTRY_LEVEL"], as_index=False)[WEIGHT_COL]
                 .sum()
                 .rename(columns={WEIGHT_COL: "emp"}))
    edu_cat["share"] = edu_cat["emp"] / edu_cat.groupby("is_specialized")["emp"].transform("sum")
    piv = (edu_cat.pivot(index="ENTRY_LEVEL", columns="is_specialized", values="share").fillna(0))
    piv.columns = ["Not specialized (LQ<1)", "Specialized (LQ≥1)"]
    piv = piv.reindex([x for x in edu_order if x in piv.index] + [x for x in piv.index if x not in edu_order])
    wrap_width = 13  # adjust: smaller = more line breaks
    labels = [textwrap.fill(str(lbl), width=wrap_width) for lbl in piv.index]
    print(cat)
    x = np.arange(len(piv.index))
    fig, ax = plt.subplots(figsize=(10, 5.2))
    ax.bar(x - width/2, piv.get("Specialized (LQ≥1)", 0), width, label="Specialized (LQ≥1)", color = "#6d9ebc")
    ax.bar(x + width/2, piv.get("Not specialized (LQ<1)", 0), width, label="Not specialized (LQ<1)", color = "#ffab40")
    ax.set_ylabel("Share of employment")
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=0, ha="center")
    ax.set_ylim(0, max(piv.max()) * 1.2 if piv.size else 1)
    ax.legend()
    sns.despine()
    plt.show()
# Out:
# Advanced Manufacturing & MRO
# Engineering & Digital
# Operations & Management
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-f9c9676a3cd8> in <module>
#       5     edu_cat["share"] = edu_cat["emp"] / edu_cat.groupby("is_specialized")["emp"].transform("sum")
#       6     piv = (edu_cat.pivot(index="ENTRY_LEVEL", columns="is_specialized", values="share").fillna(0))
# ----> 7     piv.columns = ["Not specialized (LQ<1)", "Specialized (LQ≥1)"]
#       8     piv = piv.reindex([x for x in edu_order if x in piv.index] + [x for x in piv.index if x not in edu_order])
#       9     wrap_width = 13  # adjust: smaller = more line breaks
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    6000         try:
#    6001             object.__getattribute__(self, name)
# ...

# %%
#def_occ.to_excel(OUTPUTS_DIR + "defense_occupations_detailed.xlsx", index=False)

# %%
def_df.loc[def_df["industry_part"].eq("defense_part")].groupby(["OCC_CODE", "OCC_TITLE", "critical_flag", "wage_premium_sd_vs_us"])["EMP_FINAL"].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-ff7583bf15cf> in <module>
# ----> 1 def_df.loc[def_df["industry_part"].eq("defense_part")].groupby(["OCC_CODE", "OCC_TITLE", "critical_flag", "wage_premium_sd_vs_us"])["EMP_FINAL"].sum().reset_index()
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1769                 "Use a list instead."
#    1770             )
# -> 1771         return super().__getitem__(key)
#    1772
#    1773     def _gotitem(self, key, ndim: int, subset=None):
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
# ...

# %% [markdown]
# ## Universities database

# %%
df_sd["OCC_CAT"] = df_sd.apply(lambda x: categorize_occ(x["OCC_CODE"], x["OCC_TITLE"]), axis=1)
df_sd.head()
# Out:
#          AREA                          AREA_TITLE  AREA_TYPE PRIM_STATE  \
# 121572  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA
# 121947  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA
# 122132  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA
# 122223  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA
# 122494  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA
#
#          NAICS     NAICS_TITLE         I_GROUP  OWN_CODE OCC_CODE  \
# 121572  000000  Cross-industry  cross-industry      1235  11-1011
# 121947  000000  Cross-industry  cross-industry      1235  11-1021
# 122132  000000  Cross-industry  cross-industry      1235  11-1031
# 122223  000000  Cross-industry  cross-industry      1235  11-2011
# 122494  000000  Cross-industry  cross-industry      1235  11-2021
#
#                                   OCC_TITLE  ... A_PCT90  ANNUAL HOURLY  \
# ...

# %%
univ_database = pd.read_csv(DATASETS_OCCUPATIONS + "c2024_a.csv")
univ_database.head()
# Out:
#    UNITID  CIPCODE  MAJORNUM  AWLEVEL XCTOTALT  CTOTALT XCTOTALM  CTOTALM  \
# 0  100654   1.0999         1        5        R       12        R        2
# 1  100654   1.1001         1        5        R       10        R        1
# 2  100654   1.1001         1        7        R        7        R        1
# 3  100654   1.1001         1       17        R        6        R        3
# 4  100654   1.9999         1        5        R        2        R        1
#
#   XCTOTALW  CTOTALW  ... XCUNKNM  CUNKNM XCUNKNW  CUNKNW XCNRALT  CNRALT  \
# 0        R       10  ...       Z       0       Z       0       Z       0
# 1        R        9  ...       Z       0       Z       0       Z       0
# 2        R        6  ...       Z       0       Z       0       R       2
# 3        R        3  ...       R       0       R       2       R       3
# 4        R        1  ...       Z       0       Z       0       Z       0
#
#   XCNRALM  CNRALM XCNRALW  CNRALW
# 0       Z       0       Z       0
# ...

# %%
cip_to_soc = pd.read_excel(DATASETS_OCCUPATIONS + "CIP2020_SOC2018_Crosswalk.xlsx", sheet_name = "SOC-CIP")
cip_to_soc.rename(columns = {"CIP2020Code":"CIPCODE", "SOC2018Code":"OCC_CODE", "SOC2018Title": "OCC_TITLE"}, inplace=True)
cip_to_soc.head()
# Out:
#   OCC_CODE         OCC_TITLE  CIPCODE  \
# 0  11-1011  Chief Executives  44.0401
# 1  11-1011  Chief Executives  52.0101
# 2  11-1011  Chief Executives  52.0201
# 3  11-1011  Chief Executives  52.0206
# 4  11-1011  Chief Executives  52.0701
#
#                                        CIP2020Title
# 0                            Public Administration.
# 1                       Business/Commerce, General.
# 2  Business Administration and Management, General.
# 3      Non-Profit/Public/Organizational Management.
# 4         Entrepreneurship/Entrepreneurial Studies.

# %%
universities_sd = pd.read_excel(DATASETS_OCCUPATIONS + "universities_sd.xlsx")
universities_sd.head()
# Out:
#    UNITID                                      INSTNM             IALIAS  \
# 0  109730      Associated Technical College-San Diego                NaN
# 1  109934                  Bellus Academy-Chula Vista     Bellus Academy
# 2  110468  Alliant International University-San Diego            Alliant
# 3  110680          University of California-San Diego  UCSD UC San Diego
# 4  111054              California Hair Design Academy                NaN
#
#                                   ADDR         CITY STABBR         ZIP  FIPS  \
# 0  2650 Camino Del Rio North, Ste. 100    San Diego     CA  92108-1630     6
# 1              970 Broadway, Suite 110  Chula Vista     CA       91911     6
# 2                  10455 Pomerado Road    San Diego     CA       92131     6
# 3                       9500 Gilman Dr     La Jolla     CA       92093     6
# 4    8011 University Avenue, Suite A-2      La Mesa     CA  91942-5055     6
#
# ...

# %%
univ_database_sd = univ_database.merge(universities_sd[["UNITID", "INSTNM"]], on="UNITID", how="inner")
univ_database_sd = univ_database_sd.merge(cip_to_soc[["CIPCODE", "CIP2020Title","OCC_CODE", "OCC_TITLE"]], left_on="CIPCODE", right_on="CIPCODE", how="left")
univ_database_sd.shape
# Out:
# (12236, 68)

# %%
univ_database_sd.to_excel(OUTPUTS_DIR + "univ_database_sd.xlsx", index=False)
# Out:
# <ipython-input-108-bf738e59e49d>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   univ_database_sd.to_excel(OUTPUTS_DIR + "univ_database_sd.xlsx", index=False)

# %%
programs_by_occ = univ_database_sd.groupby(["OCC_CODE","CIP2020Title"])["CTOTALT"].sum().reset_index().sort_values(["OCC_CODE","CTOTALT"], ascending=[True,False])
programs_by_occ.sort_values(by= "CTOTALT", ascending=False).head(2)
# Out:
#    OCC_CODE                                      CIP2020Title  CTOTALT
# 0   11-1011  Business Administration and Management, General.     8265
# 25  11-2022  Business Administration and Management, General.     8265

# %%
grads_by_occ = (df_key.groupby(["OCC_CODE", "OCC_TITLE"])["CTOTALT"].sum().reset_index().sort_values("CTOTALT", ascending=False))
grads_by_occ.head()
# Out:
#   OCC_CODE                                        OCC_TITLE  CTOTALT
# 7  15-2051                                  Data Scientists     4488
# 4  15-1252                              Software Developers     3358
# 5  15-1253  Software Quality Assurance Analysts and Testers     3007
# 6  15-1299                  Computer Occupations, All Other     2715
# 3  15-1251                             Computer Programmers     2225

# %%
ocupaciones_clave = ["53-7062","53-7065","15-1252","49-9071","53-3032","47-2031","51-2090","53-3033",
"15-1299","47-2061","47-1011","47-2111","17-2051","51-9061","15-1232","53-7064","53-1047","15-1211",
"49-3023","47-2152","51-2028","51-1011","49-1011","47-2141","17-2072","51-9199","53-7061","53-7051",
"17-2141","51-9111","17-2112","17-2061","17-2199","47-2073","15-1244","51-4121","15-2051","49-9099",
"49-9021","15-1253","51-4041","53-3053","17-2071","17-3023","53-3031","49-3011","19-4099","51-9198","15-1251","47-2181","49-9041"]
df_key = df_sd[df_sd["OCC_CODE"].isin(ocupaciones_clave)]

# %%
df_key = df_key.merge(grads_by_occ[["OCC_CODE", "CTOTALT"]], on="OCC_CODE", how="left")
df_key["CTOTALT"] = df_key["CTOTALT"].fillna(0)
df_key.head()
# Out:
#     AREA                          AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS  \
# 0  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA  000000
# 1  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA  000000
# 2  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA  000000
# 3  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA  000000
# 4  41740  San Diego-Chula Vista-Carlsbad, CA          4         CA  000000
#
#       NAICS_TITLE         I_GROUP  OWN_CODE OCC_CODE  \
# 0  Cross-industry  cross-industry      1235  15-1211
# 1  Cross-industry  cross-industry      1235  15-1232
# 2  Cross-industry  cross-industry      1235  15-1244
# 3  Cross-industry  cross-industry      1235  15-1251
# 4  Cross-industry  cross-industry      1235  15-1252
#
#                                      OCC_TITLE  ... ANNUAL  HOURLY  \
# 0                    Computer Systems Analysts  ...    NaN     NaN
# ...

# %%
univ_database_sd.loc[univ_database_sd["OCC_CODE"].isin(ocupaciones_clave)].groupby(["CIPCODE", "CIP2020Title"])["CTOTALT"].sum().reset_index().sort_values("CTOTALT", ascending=False).head(10)
# Out:
#     CIPCODE                                       CIP2020Title  CTOTALT
# 7   11.0701                                  Computer Science.     9020
# 2   11.0103                            Information Technology.     1716
# 23  14.1001            Electrical and Electronics Engineering.     1449
# 49  30.0801                  Mathematics and Computer Science.     1074
# 20  14.0901                     Computer Engineering, General.     1038
# 13  11.1003  Computer and Information Systems Security/Audi...      984
# 53  43.0104                   Criminal Justice/Safety Studies.      869
# 61  46.0302                                       Electrician.      828
# 44  27.0101                              Mathematics, General.      545
# 27  14.1901                            Mechanical Engineering.      530

# %%
df_key[["OCC_CODE", "OCC_TITLE", "CTOTALT"]].sort_values("CTOTALT", ascending=False).head(20)
# Out:
#    OCC_CODE                                          OCC_TITLE    CTOTALT
# 7   15-2051                                    Data Scientists 4,488.0000
# 4   15-1252                                Software Developers 3,358.0000
# 5   15-1253    Software Quality Assurance Analysts and Testers 3,007.0000
# 6   15-1299                    Computer Occupations, All Other 2,715.0000
# 3   15-1251                               Computer Programmers 2,225.0000
# 16  19-4099  Life, Physical, and Social Science Technicians... 1,247.0000
# 2   15-1244        Network and Computer Systems Administrators 1,100.0000
# 9   17-2061                        Computer Hardware Engineers   846.0000
# 10  17-2071                               Electrical Engineers   588.0000
# 11  17-2072             Electronics Engineers, Except Computer   588.0000
# 0   15-1211                          Computer Systems Analysts   566.0000
# 27  49-3023       Automotive Service Technicians and Mechanics   549.0000
# ...

# %%
graduates_by_cat = df_key.groupby("OCC_CAT")["CTOTALT"].sum().reset_index()
# Out:
#                         OCC_CAT     CTOTALT
# 0  Advanced Manufacturing & MRO  2,197.0000
# 1         Engineering & Digital 22,100.0000

# %%
employment_by_cat = (
    df_key.groupby("OCC_CAT")["TOT_EMP"]
    .sum()
    .reset_index()
    .sort_values("TOT_EMP", ascending=False)
)

# %%
pipeline = employment_by_cat.merge(graduates_by_cat, on="OCC_CAT", how="left")
pipeline["graduates_per_worker"] = (pipeline["CTOTALT"] / pipeline["TOT_EMP"])
pipeline
# Out:
#                         OCC_CAT      TOT_EMP     CTOTALT  graduates_per_worker
# 0  Advanced Manufacturing & MRO 200,170.0000  2,197.0000                0.0110
# 1         Engineering & Digital  77,720.0000 22,100.0000                0.2844

# %%
# degrees_by_occ = (df_key.groupby(["OCC_CODE","CIP2020Title"])["CTOTALT"].sum().reset_index().sort_values(["OCC_CODE","CTOTALT"], ascending=[True,False]))
# degrees_by_occ

# %%
universities = (df_key.groupby("INSTNM")["CTOTALT"].sum().reset_index().sort_values("CTOTALT", ascending=False))
universities["share"] = universities["CTOTALT"] / universities["CTOTALT"].sum()
universities
# Out:
#                                         INSTNM  CTOTALT  share
# 24          University of California-San Diego    10143 0.4175
# 19                  San Diego State University     3229 0.1329
# 5       California State University-San Marcos     1452 0.0598
# 2                           Ashford University     1378 0.0567
# 25                     University of San Diego      915 0.0377
# 4    California Institute of Arts & Technology      887 0.0365
# 7                            Grossmont College      716 0.0295
# 21                     UEI College-Chula Vista      700 0.0288
# 10                         National University      696 0.0286
# 18                   San Diego Miramar College      670 0.0276
# 12                             Palomar College      584 0.0240
# 22                       UEI College-Oceanside      502 0.0207
# 9                            MiraCosta College      470 0.0193
# 17                      San Diego Mesa College      347 0.0143
# ...

# %%
grads_by_occ = df_key.groupby("OCC_CODE")["CTOTALT"].sum().reset_index()
grads_by_occ
# Out:
#   OCC_CODE  CTOTALT
# 0  17-2011     1244
# 1  17-3021        0
# 2  51-2011       27

# %%
universities_by_occ = df_key.groupby(["OCC_CODE","INSTNM"])["CTOTALT"].sum().reset_index().sort_values(["OCC_CODE","CTOTALT"], ascending=[True,False])
universities_by_occ
# Out:
#   OCC_CODE                                  INSTNM  CTOTALT
# 3  17-2011      University of California-San Diego      676
# 2  17-2011              San Diego State University      463
# 4  17-2011                 University of San Diego       74
# 0  17-2011  California State University-San Marcos       23
# 1  17-2011                     National University        8
# 5  17-3021                     National University        0
# 6  17-3021                  San Diego City College        0
# 7  51-2011               San Diego Miramar College       27

# %% [markdown]
# ## Export results

# %%
with pd.ExcelWriter(OUTPUTS_DIR + f"outputs_occupation.xlsx", engine="xlsxwriter") as writer:
    nat_matrix.to_excel(writer, sheet_name="naics_soc_matrix_national", index=True)
    nat_agg.to_excel(writer, sheet_name="naics_soc_aggregated_national", index=True)
    sd_matrix.to_excel(writer, sheet_name="naics_soc_matrix_sd", index=True)
    sd_agg.to_excel(writer, sheet_name="naics_soc_aggregated_sd", index=True)
    crit.to_excel(writer, sheet_name="critical_occupations_sd", index=False)
    #df_states_strategic_sectors.to_excel(writer, sheet_name="states_strategic_sectors", index=False)
    naics_to_sector.to_excel(writer, sheet_name="naics_to_sector_mapping", index=False)
