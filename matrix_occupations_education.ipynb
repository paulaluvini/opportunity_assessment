# %%
import pandas as pd
import numpy as np

# %%
DATASETS_OCCUPATIONS = "./datasets_occupations/"
DATASETS_LABOR = './datasets_labor_metropolitan_area/'

# %%
df_labor = pd.read_parquet(DATASETS_LABOR + "df_labor_usa_metropolitan_area_N2022.parquet",engine='fastparquet')
df_labor['NAICS_2022'] = df_labor['NAICS_2022'].astype(str) # Ensure NAICS is string*
df_labor['naics_level'] = df_labor['NAICS_2022'].str.len() # Add a column for NAICS code length
mask_5digit = df_labor["NAICS_2022"].str.len().eq(6) & df_labor["NAICS_2022"].str.isnumeric()
df_labor = df_labor[mask_5digit]
print(df_labor.shape)
df_labor.head()
# Out:
# (213397, 4)
#   NAICS_2022 metropolitan statistical area/micropolitan statistical area  EMP  \
# 0     113110                                              10780             7
# 1     113110                                              11660             7
# 2     113110                                              12060            50
# 3     113110                                              12260            12
# 4     113110                                              12620            31
#
#    naics_level
# 0            6
# 1            6
# 2            6
# 3            6
# 4            6

# %%
df_occupations = pd.read_excel(DATASETS_OCCUPATIONS + "all_data_M_2024.xlsx", sheet_name="All May 2024 data")
df_occupations["NAICS"] = df_occupations["NAICS"].astype(str)
df_occupations.head()
# Out:
#    AREA AREA_TITLE  AREA_TYPE PRIM_STATE   NAICS     NAICS_TITLE  \
# 0    99       U.S.          1         US  000000  Cross-industry
# 1    99       U.S.          1         US  000000  Cross-industry
# 2    99       U.S.          1         US  000000  Cross-industry
# 3    99       U.S.          1         US  000000  Cross-industry
# 4    99       U.S.          1         US  000000  Cross-industry
#
#           I_GROUP  OWN_CODE OCC_CODE               OCC_TITLE  ... H_PCT75  \
# 0  cross-industry      1235  00-0000         All Occupations  ...   37.89
# 1  cross-industry      1235  11-0000  Management Occupations  ...    82.5
# 2  cross-industry      1235  11-1000          Top Executives  ...   81.01
# 3  cross-industry      1235  11-1010        Chief Executives  ...       #
# 4  cross-industry      1235  11-1011        Chief Executives  ...       #
#
#   H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY NAICS_CLEAN
# 0   60.44   29990   36730    49500   78810  125720    NaN    NaN      000000
# 1       #   57010   79900   122090  171610       #    NaN    NaN      000000
# 2       #   47510   68800   104990  168490       #    NaN    NaN      000000
# 3       #   73710  126080   206420       #       #    NaN    NaN      000000
# 4       #   73710  126080   206420       #       #    NaN    NaN      000000
#
# [5 rows x 33 columns]

# %%
naics_ref = pd.read_excel(DATASETS_LABOR + "NAICS_EQUIVALENCE.xlsx")
naics_ref['naics_code'] = naics_ref['naics_code'].astype(str)
naics_ref.head()
# Out:
#   naics_code                           naics_description  level parent_code  \
# 0         11  Agriculture, Forestry, Fishing and Hunting      2         NaN
# 1        111                             Crop Production      3          11
# 2       1111                   Oilseed and Grain Farming      4         111
# 3      11111                             Soybean Farming      5         111
# 4     111110                             Soybean Farming      6        1111
#
#   automotive_subsector supply_chain_stage sector_alignment strategic_sector
# 0               Others             Others              NaN              NaN
# 1               Others             Others              NaN              NaN
# 2               Others             Others              NaN              NaN
# 3               Others             Others              NaN              NaN
# 4               Others             Others              NaN              NaN

# %%
df_occupations["NAICS_CLEAN"] = df_occupations["NAICS_CLEAN"].astype(str).str.upper().str.replace(r"[^0-9A-Z]", "", regex=True)
level_map = {"cross-industry": 0,"cross-industry, ownership": 0,"sector": 2,"3-digit": 3,"3-digit, ownership": 3,"4-digit": 4,"4-digit, ownership": 4,
    "5-digit": 5,"6-digit": 6,}
df_occupations["i_group_clean"] = df_occupations["I_GROUP"].astype(str).str.strip().str.lower()
df_occupations["naics_len"] = df_occupations["i_group_clean"].map(level_map)
df_occupations["naics_len"].unique()
# Out:
# array([0, 2, 3, 4, 6, 5], dtype=int64)

# %%
df_occupations = df_occupations.merge(naics_ref[['naics_code', 'naics_description']], left_on=['NAICS_CLEAN'], right_on=['naics_code'], how='left')

# %%
df_occupations.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY', 'NAICS_CLEAN', 'i_group_clean',
#        'naics_len', 'naics_code', 'naics_description'],
#       dtype='object')

# %% [markdown]
# ### Build occupation matrix

# %%
df_nat = df_occupations.loc[(df_occupations["AREA"] == 99)].copy()
df_sd = df_occupations.loc[(df_occupations["AREA"] == 41740)].copy()

# %%
df_occupations.loc[(df_occupations["NAICS_CLEAN	"] == 99)].shape
# Out:
#            AREA                                         AREA_TITLE  AREA_TYPE  \
# 0            99                                               U.S.          1
# 1            99                                               U.S.          1
# 2            99                                               U.S.          1
# 3            99                                               U.S.          1
# 4            99                                               U.S.          1
# ...         ...                                                ...        ...
# 416548  5500002        Northeastern Wisconsin nonmetropolitan area          6
# 416549  5500003       South Central Wisconsin nonmetropolitan area          6
# 416550  5500004             Western Wisconsin nonmetropolitan area          6
# 416551   800001  Eastern and Southern Colorado nonmetropolitan ...          6
# 416552   800003            Northwest Colorado nonmetropolitan area          6
#
#        PRIM_STATE   NAICS     NAICS_TITLE         I_GROUP  OWN_CODE OCC_CODE  \
# 0              US  000000  Cross-industry  cross-industry      1235  00-0000
# 1              US  000000  Cross-industry  cross-industry      1235  11-0000
# 2              US  000000  Cross-industry  cross-industry      1235  11-1000
# 3              US  000000  Cross-industry  cross-industry      1235  11-1010
# 4              US  000000  Cross-industry  cross-industry      1235  11-1011
# ...           ...     ...             ...             ...       ...      ...
# 416548         WI  000000  Cross-industry  cross-industry      1235  53-7199
# 416549         WI  000000  Cross-industry  cross-industry      1235  53-7199
# 416550         WI  000000  Cross-industry  cross-industry      1235  53-7199
# 416551         CO  000000  Cross-industry  cross-industry      1235  53-7199
# 416552         CO  000000  Cross-industry  cross-industry      1235  53-7199
#
#                                  OCC_TITLE  ... A_MEDIAN A_PCT75 A_PCT90  \
# 0                          All Occupations  ...    49500   78810  125720
# 1                   Management Occupations  ...   122090  171610       #
# 2                           Top Executives  ...   104990  168490       #
# 3                         Chief Executives  ...   206420       #       #
# 4                         Chief Executives  ...   206420       #       #
# ...                                    ...  ...      ...     ...     ...
# 416548  Material Moving Workers, All Other  ...    29210   34080   34080
# 416549  Material Moving Workers, All Other  ...    30680   33800   33910
# 416550  Material Moving Workers, All Other  ...    31700   33910   61690
# 416551  Material Moving Workers, All Other  ...    39070   45650   54430
# 416552  Material Moving Workers, All Other  ...    71160   71160   71560
#
#        ANNUAL HOURLY NAICS_CLEAN   i_group_clean naics_len naics_code  \
# 0         NaN    NaN      000000  cross-industry         0        NaN
# 1         NaN    NaN      000000  cross-industry         0        NaN
# 2         NaN    NaN      000000  cross-industry         0        NaN
# 3         NaN    NaN      000000  cross-industry         0        NaN
# 4         NaN    NaN      000000  cross-industry         0        NaN
# ...       ...    ...         ...             ...       ...        ...
# 416548    NaN    NaN      000000  cross-industry         0        NaN
# 416549    NaN    NaN      000000  cross-industry         0        NaN
# 416550    NaN    NaN      000000  cross-industry         0        NaN
# 416551    NaN    NaN      000000  cross-industry         0        NaN
# 416552    NaN    NaN      000000  cross-industry         0        NaN
#
#        naics_description
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 416548               NaN
# 416549               NaN
# 416550               NaN
# 416551               NaN
# 416552               NaN
#
# [416553 rows x 37 columns]

# %%
def add_naics_hierarchy(df, naics_col="naics_code"):
    out = df.copy()

    # Make sure NAICS is a clean string of digits
    out[naics_col] = out[naics_col].astype(str).str.strip()
    out = out.loc[out[naics_col].str.fullmatch(r"\d+")]  # keep only numeric NAICS

    # NAICS levels to display (you can add 5 if you use it)
    levels = [2, 3, 4, 5, 6]

    rows = []
    for L in levels:
        tmp = out.loc[out[naics_col].str.len().ge(L)].copy()
        tmp["NAICS_LEVEL"] = L
        tmp["NAICS_HIER"] = tmp[naics_col].str.slice(0, L)
        rows.append(tmp)

    long = pd.concat(rows, ignore_index=True)
    return long

# %%
nat_long = add_naics_hierarchy(df_nat, naics_col="naics_code")
sd_long  = add_naics_hierarchy(df_sd,  naics_col="naics_code")

# %%
def build_naics_soc_matrix(long_df):
    # pick what you want to aggregate; TOT_EMP is the usual weight
    agg = (long_df
           .groupby(["AREA", "AREA_TITLE", "AREA_TYPE", "PRIM_STATE",
                     "NAICS_LEVEL", "NAICS_HIER",
                     "OCC_CODE", "OCC_TITLE"], as_index=False)
           .agg(
               TOT_EMP=("TOT_EMP", "sum"),
               # optional extras:
               # A_MEAN=("A_MEAN", "mean"),   # careful: means should be weighted if needed
               # H_MEAN=("H_MEAN", "mean"),
               N_ROWS=("OCC_CODE", "size")
           ))

    # Wide “matrix” (NAICS x SOC) using TOT_EMP
    mat = agg.pivot_table(
        index=["NAICS_LEVEL", "NAICS_HIER"],
        columns="OCC_CODE",
        values="TOT_EMP",
        aggfunc="sum",
        fill_value=0
    )

    return agg, mat

nat_agg, nat_matrix = build_naics_soc_matrix(nat_long)
sd_agg,  sd_matrix  = build_naics_soc_matrix(sd_long)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-c332678645d7> in <module>
#      24     return agg, mat
#      25
# ---> 26 nat_agg, nat_matrix = build_naics_soc_matrix(nat_long)
#      27 sd_agg,  sd_matrix  = build_naics_soc_matrix(sd_long)
#
# <ipython-input-24-c332678645d7> in build_naics_soc_matrix(long_df)
#       1 def build_naics_soc_matrix(long_df):
#       2     # pick what you want to aggregate; TOT_EMP is the usual weight
# ----> 3     agg = (long_df
#       4            .groupby(["AREA", "AREA_TITLE", "AREA_TYPE", "PRIM_STATE",
#       5                      "NAICS_LEVEL", "NAICS_HIER",
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1267
#    1268         op = GroupByApply(self, func, args, kwargs)
# -> 1269         result = op.agg()
#    1270         if not is_dict_like(func) and result is not None:
#    1271             return result
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
#     164         elif is_list_like(arg):
#     165             # we require a list, but not a 'str'
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\apply.py in agg_dict_like(self)
#     418             else:
#     419                 # key used for column selection and output
# --> 420                 results = {
#     421                     key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422                 }
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\apply.py in <dictcomp>(.0)
#     419                 # key used for column selection and output
#     420                 results = {
# --> 421                     key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422                 }
#     423
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     236             # but not the class list / tuple itself.
#     237             func = maybe_mangle_lambdas(func)
# --> 238             ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     239             if relabeling:
#     240                 # columns is not narrowed by mypy from relabeling flag
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     314             for idx, (name, func) in enumerate(arg):
#     315                 key = base.OutputKey(label=name, position=idx)
# --> 316                 results[key] = self.aggregate(func, *args, **kwargs)
#     317
#     318         if any(isinstance(x, DataFrame) for x in results.values()):
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     230
#     231         if isinstance(func, str):
# --> 232             return getattr(self, func)(*args, **kwargs)
#     233
#     234         elif isinstance(func, abc.Iterable):
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2261             # _agg_general() returns. GH #31422
#    2262             with com.temp_setattr(self, "observed", True):
# -> 2263                 result = self._agg_general(
#    2264                     numeric_only=numeric_only,
#    2265                     min_count=min_count,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1420         npfunc: Callable,
#    1421     ):
# -> 1422         result = self._cython_agg_general(
#    1423             how=alias,
#    1424             alt=npfunc,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1505             return result
#    1506
# -> 1507         new_mgr = data.grouped_reduce(array_func)
#    1508         res = self._wrap_agged_manager(new_mgr)
#    1509         out = self._wrap_aggregated_output(res)
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\internals\base.py in grouped_reduce(self, func)
#     195     def grouped_reduce(self, func):
#     196         arr = self.array
# --> 197         res = func(arr)
#     198         index = default_index(len(res))
#     199
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in array_func(values)
#    1488         def array_func(values: ArrayLike) -> ArrayLike:
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#    1492                     values,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     957         ids, _, _ = self.group_info
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#     961             axis=axis,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     655             )
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#     659             min_count=min_count,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     480             if result_mask is not None:
#     481                 result_mask = result_mask[None, :]
# --> 482             res = self._call_cython_op(
#     483                 values2d,
#     484                 min_count=min_count,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     547             counts = np.zeros(ngroups, dtype=np.int64)
#     548             if self.how in ["min", "max", "mean", "last", "first", "sum"]:
# --> 549                 func(
#     550                     out=result,
#     551                     counts=counts,
#
# d:\Informacion\DELL\Anaconda\lib\site-packages\pandas\_libs\groupby.pyx in pandas._libs.groupby.group_sum()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Education
